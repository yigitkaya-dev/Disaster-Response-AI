# %% [markdown]
# This notebook is mainly for exploration of things like:
#
# 1. Open one xBD image
# 2. Open one JSON label
# 3. Display polygons
# 4. Check damage labels
# 5. Count how many buildings exist per class
# 6. Test crop size
# 7. Visualize a few cropped buildings
